# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500)

# %%
data_2015 = pd.read_csv('world-happiness/2015.csv')
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_2016 = pd.read_csv('world-happiness/2016.csv')
data_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
data_2017 = pd.read_csv('world-happiness/2017.csv')
data_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
data_2018 = pd.read_csv('world-happiness/2018.csv')
data_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
data_2019 = pd.read_csv('world-happiness/2019.csv')
data_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
data_comb = pd.DataFrame()
data_comb['Country'] = data_2015['Country']
data_comb['2015'] = data_2015['Happiness Score']
data_comb = pd.merge(
    data_comb, data_2016.loc[:,['Country', 'Happiness Score']], left_on='Country', right_on='Country'
)
data_comb.rename(columns={'Happiness Score':'2016'}, inplace=True)
data_comb = pd.merge(
    data_comb, data_2017.loc[:,['Country', 'Happiness.Score']], left_on='Country', right_on='Country'
)
data_comb.rename(columns={'Happiness.Score':'2017'}, inplace=True)
data_comb = pd.merge(
    data_comb, data_2018.loc[:,['Country or region', 'Score']], left_on='Country', right_on='Country or region'
)
data_comb.rename(columns={'Score':'2018'}, inplace=True)
data_comb = pd.merge(
    data_comb, data_2019.loc[:,['Country or region', 'Score']], left_on='Country', right_on='Country or region'
)
data_comb.rename(columns={'Score':'2019'}, inplace=True)
data_comb.drop(['Country or region_x', 'Country or region_y'], axis=1, inplace=True)
data_comb.set_index('Country', inplace=True)
data_comb
# Out:
#               2015   2016   2017   2018   2019
# Country
# Switzerland  7.587  7.509  7.494  7.487  7.480
# Iceland      7.561  7.501  7.504  7.495  7.494
# Denmark      7.527  7.526  7.522  7.555  7.600
# Norway       7.522  7.498  7.537  7.594  7.554
# Canada       7.427  7.404  7.316  7.328  7.278
# ...            ...    ...    ...    ...    ...
# Rwanda       3.465  3.515  3.471  3.408  3.334
# Benin        3.340  3.484  3.657  4.141  4.883
# Syria        3.006  3.069  3.462  3.462  3.462
# Burundi      2.905  2.905  2.905  2.905  3.775
# Togo         2.839  3.303  3.495  3.999  4.085
#
# [141 rows x 5 columns]

# %% [markdown]
# # Plot 1

# %%
plt.figure(figsize=(20,10))
fg = plt.scatter(
    data=data_2016, x='Happiness Score', y='Economy (GDP per Capita)', 
)
plt.xlabel("Happiness Score")
plt.ylabel("Economy (GDP per Capita)")
plt.show()

# %%
fg = sns.regplot(
    data=data_2016, x='Happiness Score', y='Economy (GDP per Capita)'
)

# %%
def plot_ci_manual(t, s_err, n, x, x2, y2, ax=None):
    """Return an axes of confidence bands using a simple approach.

    Notes
    -----
    .. math:: \left| \: \hat{\mu}_{y|x0} - \mu_{y|x0} \: \right| \; \leq \; T_{n-2}^{.975} \; \hat{\sigma} \; \sqrt{\frac{1}{n}+\frac{(x_0-\bar{x})^2}{\sum_{i=1}^n{(x_i-\bar{x})^2}}}
    .. math:: \hat{\sigma} = \sqrt{\sum_{i=1}^n{\frac{(y_i-\hat{y})^2}{n-2}}}

    References
    ----------
    .. [1] M. Duarte.  "Curve fitting," Jupyter Notebook.
       http://nbviewer.ipython.org/github/demotu/BMC/blob/master/notebooks/CurveFitting.ipynb

    """
    if ax is None:
        ax = plt.gca()

    ci = t * s_err * np.sqrt(1/n + (x2 - np.mean(x))**2 / np.sum((x - np.mean(x))**2))
    plt.fill_between(x2, y2 + ci, y2 - ci, color="#b9cfe7", edgecolor="")

    return ax


def equation(a, b):
    """Return a 1D polynomial."""
    return np.polyval(a, b)

# %%
import scipy.stats as stats
n = data_2016['Economy (GDP per Capita)'].size 
                              # used for CI and PI bands
p, cov = np.polyfit(data_2016['Happiness Score'], data_2016['Economy (GDP per Capita)'], 1, cov=True) 
m = p.size 
t = stats.t.ppf(0.975, n - m)
y_model = equation(p, data_2016['Happiness Score'])  
resid = data_2016['Economy (GDP per Capita)'] - y_model
dof = n - m
s_err = np.sqrt(np.sum(resid**2) / dof) 
   
x2 = np.linspace(np.min(data_2016['Happiness Score']), np.max(data_2016['Happiness Score']), 100)
y2 = equation(p, x2)

# %%
plt.figure(figsize=(20,10))
plt.scatter(x=data_2016['Happiness Score'], y=data_2016['Economy (GDP per Capita)'], c='#CCCCCC')
b, a = np.polyfit(data_2016['Happiness Score'], data_2016['Economy (GDP per Capita)'], 1)
yfit = [a + b * xi for xi in data_2016['Happiness Score']]
plot_ci_manual(t, s_err, n, data_2016['Happiness Score'], x2, y2)
plt.plot(data_2016['Happiness Score'], yfit, c='r')
plt.title("More money = more happy?", fontsize="18", fontweight="bold")
plt.xlabel("Happiness Score", fontsize="18")
plt.ylabel("Economy (GDP per Capita)", fontsize="18")
plt.show()

# %% [markdown]
# # Plot 2

# %%
g = sns.catplot(
    x="Region", y="Health (Life Expectancy)", kind="box", data=data_2016)
g.set_xticklabels(rotation=90)
g.fig.set_size_inches(20,10)

# %%
g=sns.catplot(
    x="Region", y="Health (Life Expectancy)", kind="box", data=data_2016, 
    order=data_2016.groupby('Region').median()['Health (Life Expectancy)'].sort_values(ascending=False).index,
    palette=['#009E73', '#009E73', '#009E73', '#009E73', '#E69F00', '#E69F00', '#E69F00', '#E69F00', '#E69F00', '#D55E00']
)
plt.xticks(rotation=90, fontsize="18")
plt.title("More healthy = more happy?", fontsize="18", fontweight="bold")
plt.xlabel("Region", fontsize="18")
plt.ylabel("Health (Life Expectancy)", fontsize="18")
g.fig.set_size_inches(20,10)
plt.show()

# %% [markdown]
# # Plot 3

# %%
plt.figure(figsize=(20,10))

fg = plt.scatter(
    data=data_2016, x='Happiness Score', y='Generosity', 
)

plt.xlabel("Happiness Score")
plt.ylabel("Generosity")
plt.show()

# %%
data_2016['Generosity'].idxmax()
# Out:
# 118

# %%
data_2016.loc[118]
# Out:
# Country                                    Myanmar
# Region                           Southeastern Asia
# Happiness Rank                                 119
# Happiness Score                              4.395
# Lower Confidence Interval                    4.327
# Upper Confidence Interval                    4.463
# Economy (GDP per Capita)                   0.34112
# Family                                     0.69981
# Health (Life Expectancy)                    0.3988
# Freedom                                    0.42692
# Trust (Government Corruption)              0.20243
# Generosity                                 0.81971
# Dystopia Residual                          1.50655
# Name: 118, dtype: object

# %%
plt.figure(figsize=(20,10))

fg = plt.scatter(
    data=data_2016, x='Happiness Score', y='Generosity', c='#CCCCCC'
)
plt.plot([4.395], [0.81971], marker='*', markersize=15, color="red")
plt.annotate('Myanmar', xy=(4.45, 0.82), xytext=(5, 0.9), fontsize="22",
            arrowprops=dict(facecolor='black', shrink=0.05),
        )
plt.gca().set_ylim(0,1)
plt.title("What is the most generous country in the world?", fontsize="18", fontweight="bold")
plt.xlabel("Happiness Score", fontsize="18")
plt.ylabel("Generosity", fontsize="18")
plt.show()
